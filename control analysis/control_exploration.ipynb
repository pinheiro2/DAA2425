# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %%
dfcontrol = pd.read_csv("../datasets/train_radiomics_occipital_CONTROL.csv")
dfhippo = pd.read_csv("../datasets/train_radiomics_hipocamp.csv")

# %%
dfhippo['Transition'].value_counts()
# Out:
# Transition
# CN-CN      96
# MCI-MCI    71
# MCI-AD     68
# AD-AD      60
# CN-MCI     10
# Name: count, dtype: int64

# %%
df_nao_numerico = dfcontrol.select_dtypes(exclude=[np.number])
#df_nao_numerico.info()
df_nao_numerico.describe()
# Out:
#                 ID                                              Image  \
# count          305                                                305
# unique         305                                                305
# top     006_S_0681  /notebooks/disk2/DS2_FreeSurfer/ADNI_006_S_068...
# freq             1                                                  1
#
#                                                      Mask  \
# count                                                 305
# unique                                                305
# top     /notebooks/disk2/DS2_FreeSurfer/ADNI_006_S_068...
# freq                                                    1
#
#        diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# count                               305                        305
# unique                                1                          1
# top                               2.2.0                     1.18.5
# ...

# %%
Xcontrol = dfcontrol.drop(['Transition'], axis=1)     
ycontrol = dfcontrol['Transition'].to_frame()

Xhippo = dfhippo.drop(['Transition'], axis=1) 
yhippo = dfhippo['Transition'].to_frame()

# %%
Xcontrol = Xcontrol.select_dtypes(include=[np.number])
Xhippo = Xcontrol.select_dtypes(include=[np.number])

# %%
Xcontrol_train, Xcontrol_test, ycontrol_train, ycontrol_test = train_test_split(Xcontrol, ycontrol, test_size=0.30, random_state=2021)
Xhippo_train, Xhippo_test, yhippo_train, yhippo_test = train_test_split(Xhippo, yhippo, test_size=0.30, random_state=2021)

# %%
from sklearn.linear_model import LogisticRegression
logmodel1 = LogisticRegression(random_state=2022, solver='newton-cg')
logmodel2 =LogisticRegression(random_state=2022, solver='newton-cg')
logmodel1.fit(Xcontrol_train, ycontrol_train)
logmodel2.fit(Xhippo_train, yhippo_train)
# Out:
# c:\Users\super\anaconda3\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\super\anaconda3\envs\myenv\Lib\site-packages\sklearn\utils\optimize.py:318: ConvergenceWarning: newton-cg failed to converge at loss = 0.5772193228809224. Increase the number of iterations.
#   warnings.warn(
# c:\Users\super\anaconda3\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\super\anaconda3\envs\myenv\Lib\site-packages\sklearn\utils\optimize.py:318: ConvergenceWarning: newton-cg failed to converge at loss = 0.5772193228809224. Increase the number of iterations.
# ...

# %%
predControl = logmodel1.predict(Xcontrol_test)
predHippo = logmodel2.predict(Xhippo_test)

# %%
#print("F1_SCORE CONTROL: " + confusion_matrix(ycontrol_test, predControl))
#print("F1_SCORE HIPPO: " + confusion_matrix(yhippo_test, predHippo))
print(predControl)
print(predHippo)
# Out:
# ['CN-CN' 'MCI-MCI' 'MCI-AD' 'MCI-MCI' 'MCI-MCI' 'MCI-AD' 'MCI-AD' 'CN-CN'
#  'MCI-AD' 'MCI-AD' 'CN-CN' 'MCI-MCI' 'CN-CN' 'MCI-AD' 'AD-AD' 'MCI-AD'
#  'CN-CN' 'MCI-MCI' 'MCI-AD' 'CN-CN' 'CN-CN' 'AD-AD' 'AD-AD' 'CN-CN'
#  'MCI-AD' 'MCI-MCI' 'CN-CN' 'CN-CN' 'MCI-AD' 'MCI-AD' 'AD-AD' 'CN-CN'
#  'MCI-AD' 'MCI-MCI' 'MCI-MCI' 'AD-AD' 'MCI-AD' 'CN-CN' 'AD-AD' 'MCI-AD'
#  'MCI-AD' 'CN-CN' 'MCI-AD' 'MCI-AD' 'MCI-MCI' 'MCI-MCI' 'AD-AD' 'MCI-MCI'
#  'MCI-AD' 'MCI-MCI' 'MCI-MCI' 'MCI-MCI' 'MCI-MCI' 'MCI-AD' 'MCI-MCI'
#  'CN-CN' 'AD-AD' 'CN-CN' 'MCI-MCI' 'MCI-AD' 'AD-AD' 'CN-CN' 'AD-AD'
#  'CN-CN' 'CN-CN' 'MCI-MCI' 'CN-CN' 'AD-AD' 'CN-CN' 'MCI-AD' 'AD-AD'
#  'AD-AD' 'MCI-MCI' 'AD-AD' 'MCI-MCI' 'AD-AD' 'CN-CN' 'MCI-MCI' 'MCI-MCI'
#  'MCI-AD' 'CN-CN' 'MCI-MCI' 'MCI-MCI' 'CN-CN' 'CN-CN' 'CN-CN' 'CN-CN'
#  'MCI-MCI' 'MCI-AD' 'AD-AD' 'CN-MCI' 'MCI-AD']
# ['CN-CN' 'MCI-MCI' 'MCI-AD' 'MCI-MCI' 'MCI-MCI' 'MCI-AD' 'MCI-AD' 'CN-CN'
#  'MCI-AD' 'MCI-AD' 'CN-CN' 'MCI-MCI' 'CN-CN' 'MCI-AD' 'AD-AD' 'MCI-AD'
# ...

# %%
data = pd.DataFrame({
    'RowId': np.arange(1, len(predictions) + 1), 
    'Result': predictions
})

#data.to_csv('logistic_regression_predicts.csv', index=False)
